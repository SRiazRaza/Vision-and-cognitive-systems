# %% [markdown]
# <a href="https://colab.research.google.com/github/SRiazRaza/Vision-and-cognitive-systems/blob/main/ModelEvaluation_(FasterR_CNN_101_FPN)4COA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resources and credit:
# - SSDD data download: https://github.com/TianwenZhang0825/LS-SSDD-v1.0-OPEN
# - Detectron2 docs: https://detectron2.readthedocs.io/en/latest/index.html
# - Conceptual: https://medium.com/@hirotoschwert/digging-into-detectron-2-part-5-6e220d762f9
# - Conceptual: https://jonathan-hui.medium.com/map-mean-average-precision-for-object-detection-45c121a31173

# %% [markdown]
# # Installation of detectron2 and Imports
# *Standard from Detectron2's docs*

# %% [markdown]
# *Restart after executing this cell*

# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-2ezbml9i
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-2ezbml9i
#   Resolved https://github.com/facebookresearch/detectron2.git to commit eddac5d5b4fce9b5eba5518f9ee348fa3a531407
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.12.3)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.9 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.7 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-23.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 46.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (5.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.3)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (3.7.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.54.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=7803733 sha256=0ce6d84b5bcdaaf12c343371ca06c4808b07df4207690d19d8959c328e86ed9f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-imn6hakx/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=d539db2cd950ed6001f7c0a5090949dbd5dc2d6de6a523ddbd92965cf1f1dfcc
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=c65136f368f1cb9839e5097461761ba164e6f8a3eb581b910d88e25f7c56e715
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8

# %% [markdown]
# *Restart after executing this cell*

# %%
# !nvidia-smi
# Out:
# Sun Jun 25 17:24:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    12W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %% [markdown]
# # Registration of the custom dataset to detectron2

# %%
# Function that retrieves a standard dataset compatible with detectron2
def get_dict(type):
  """ Returns a list[dict] containing information about the dataset """
  import pickle
  root = '/content/drive/MyDrive/SSDD/datasets/' + type + '/'
  with open(root + "standardDict.pkl", "rb") as input_file:
    return pickle.load(input_file)

# %%
# Global paths
datasets = '/content/drive/MyDrive/SSDD/datasets/'

# Mount Google Drive (Import files from Google Drive in Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from detectron2.structures import BoxMode

pre = 'ssdd_'

# Register
for d in ["train", "test", "test_offshore", "test_inshore", "train/train_w_val", "train/validation", "train/toy"]:
    DatasetCatalog.register(pre + d, lambda d=d: get_dict(d))
    MetadataCatalog.get(pre + d).set(thing_classes=["ship"])

# %%
# Instances of metadata
train_metadata = MetadataCatalog.get(pre + 'train')
test_metadata = MetadataCatalog.get(pre + 'test')
test_offshore_metadata = MetadataCatalog.get(pre + 'test_offshore')
test_inshore_metadata = MetadataCatalog.get(pre + 'test_inshore')
train_w_val_metadata = MetadataCatalog.get(pre + 'train/train_w_val')
validation_metadata = MetadataCatalog.get(pre + 'train/validation')
toy_metadata = MetadataCatalog.get(pre + 'train/toy')

# %% [markdown]
# # Model Loading

# %%
# %cd /content/drive/MyDrive/SSDD/
output = '/content/drive/MyDrive/SSDD/'
model_name = "./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO"  # Replace w/ folder
# Out:
# /content/drive/MyDrive/SSDD

# %%
from detectron2.engine import DefaultTrainer
# detectron2.config - https://detectron2.readthedocs.io/en/latest/modules/config.html

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_101_FPN_3x.yaml"))  # Replace w/ config
cfg.DATASETS.TRAIN = (pre + "train/train_w_val",)  # (pre + "train",)
cfg.DATASETS.TEST = ()
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (ship)
cfg.OUTPUT_DIR = model_name

cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # (default: 0.05)
cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5  # (default: 0.5)

#cfg.MODEL.DEVICE = 'cpu'

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=True)  # model loads from the last_checkpoint file, not cfg.MODEL.WEIGHTS
# Out:
# [06/25 18:06:56 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [06/25 18:06:56 d2.data.build]: Removed 4157 images with no usable annotations. 943 images left.
# [06/25 18:06:57 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/25 18:06:57 d2.data.build]: Using training sampler TrainingSampler
# [06/25 18:06:57 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:06:57 d2.data.common]: Serializing 943 elements to byte tensors and concatenating them all ...
# [06/25 18:06:57 d2.data.common]: Serialized dataset takes 0.28 MiB
# [06/25 18:06:57 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/model_final.pth ...

# %% [markdown]
# # Evaluation using the trained model
#
# To run inference using the trained model on the validation/test dataset, we first create a predictor using the model we just trained.

# %%
# Inference should use the config with parameters that are used in training
# cfg now already contains everything we've set previously. We changed it a little bit for inference:
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth") # Load custom weights
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # (default: 0.05)
cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5  # (default: 0.5)

predictor = DefaultPredictor(cfg)
# Out:
# [06/25 18:07:01 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/model_final.pth ...

# %% [markdown]
# ## Visualization
#
# We randomly select several samples to visualize the prediction results.

# %%
#from detectron2.utils.visualizer import ColorMode

dataset_dicts = get_dict("test")   # must be "test", "test_offshore", "test_inshore"

# Filter out pics w/o annotations
dataset_dicts_anns = []
for i in dataset_dicts:
  if i['annotations'] != []:
    dataset_dicts_anns.append(i)

# %%
def printImage(ann, metadata, predictor = None, predFlag = False):
  #from detectron2.utils.visualizer import Visualizer

  im = cv2.imread(ann["file_name"])
  v = Visualizer(im[:, :, ::-1],
                 metadata=metadata,
                 scale=0.5)

  if predFlag:
    outputs = predictor(im)  # format is documented at https://detectron2.readthedocs.io/tutorials/models.html#model-output-format
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  else:
    out = v.draw_dataset_dict(ann)

  image = out.get_image()[:, :, ::-1]

  return image

# %%
os.makedirs(model_name + "/predImages_eval", exist_ok=True)  # Make a directory for output images

# %%
from cv2 import hconcat
random.seed(1)
#set.seed(1)

num_samples = 3

for d in random.sample(dataset_dicts_anns, num_samples):
  image1 = printImage(d, test_metadata, predictor, True)  # Prediction
  image2 = printImage(d, test_metadata, False)  # Ground truth
  image3 = hconcat([image1, image2])

  cv2_imshow(image3) # display an image
  cv2.imwrite(model_name + '/predImages_eval/' + str(d["image_id"] + '.jpg'), image3)  # save an image
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F34043C47C0>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F3405CC5540>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F340438CF70>

# %% [markdown]
# # Evaluation using the COCO Evaluator
#
# We can also evaluate its performance using AP metric implemented in COCO API.

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# %%
# test_offshore
evaluator = COCOEvaluator('ssdd_test_offshore', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_offshore')

print(inference_on_dataset(trainer.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# [06/25 18:07:41 d2.evaluation.coco_evaluation]: Trying to convert 'ssdd_test_offshore' to COCO format ...
# WARNING [06/25 18:07:41 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/ssdd_test_offshore_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [06/25 18:07:41 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 1495         |
# |            |              |
# [06/25 18:07:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/25 18:07:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:07:41 d2.data.common]: Serializing 2234 elements to byte tensors and concatenating them all ...
# [06/25 18:07:41 d2.data.common]: Serialized dataset takes 0.41 MiB
# [06/25 18:07:41 d2.evaluation.evaluator]: Start inference on 2234 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [06/25 18:07:43 d2.evaluation.evaluator]: Inference done 11/2234. Dataloading: 0.0051 s/iter. Inference: 0.1327 s/iter. Eval: 0.0002 s/iter. Total: 0.1379 s/iter. ETA=0:05:06
# [06/25 18:07:48 d2.evaluation.evaluator]: Inference done 53/2234. Dataloading: 0.0052 s/iter. Inference: 0.1180 s/iter. Eval: 0.0003 s/iter. Total: 0.1236 s/iter. ETA=0:04:29
# [06/25 18:07:53 d2.evaluation.evaluator]: Inference done 97/2234. Dataloading: 0.0040 s/iter. Inference: 0.1156 s/iter. Eval: 0.0002 s/iter. Total: 0.1200 s/iter. ETA=0:04:16
# [06/25 18:07:58 d2.evaluation.evaluator]: Inference done 130/2234. Dataloading: 0.0048 s/iter. Inference: 0.1234 s/iter. Eval: 0.0003 s/iter. Total: 0.1287 s/iter. ETA=0:04:30
# [06/25 18:09:19 d2.evaluation.evaluator]: Inference done 786/2234. Dataloading: 0.0037 s/iter. Inference: 0.1201 s/iter. Eval: 0.0002 s/iter. Total: 0.1242 s/iter. ETA=0:02:59
# [06/25 18:09:24 d2.evaluation.evaluator]: Inference done 830/2234. Dataloading: 0.0036 s/iter. Inference: 0.1197 s/iter. Eval: 0.0002 s/iter. Total: 0.1238 s/iter. ETA=0:02:53
# [06/25 18:09:29 d2.evaluation.evaluator]: Inference done 872/2234. Dataloading: 0.0036 s/iter. Inference: 0.1196 s/iter. Eval: 0.0002 s/iter. Total: 0.1237 s/iter. ETA=0:02:48
# [06/25 18:09:34 d2.evaluation.evaluator]: Inference done 914/2234. Dataloading: 0.0036 s/iter. Inference: 0.1195 s/iter. Eval: 0.0002 s/iter. Total: 0.1235 s/iter. ETA=0:02:43
# [06/25 18:09:39 d2.evaluation.evaluator]: Inference done 957/2234. Dataloading: 0.0035 s/iter. Inference: 0.1193 s/iter. Eval: 0.0002 s/iter. Total: 0.1232 s/iter. ETA=0:02:37
# [06/25 18:09:45 d2.evaluation.evaluator]: Inference done 999/2234. Dataloading: 0.0035 s/iter. Inference: 0.1192 s/iter. Eval: 0.0002 s/iter. Total: 0.1231 s/iter. ETA=0:02:32
# [06/25 18:09:50 d2.evaluation.evaluator]: Inference done 1041/2234. Dataloading: 0.0035 s/iter. Inference: 0.1192 s/iter. Eval: 0.0002 s/iter. Total: 0.1231 s/iter. ETA=0:02:26
# [06/25 18:09:55 d2.evaluation.evaluator]: Inference done 1084/2234. Dataloading: 0.0034 s/iter. Inference: 0.1190 s/iter. Eval: 0.0002 s/iter. Total: 0.1228 s/iter. ETA=0:02:21
# [06/25 18:10:00 d2.evaluation.evaluator]: Inference done 1125/2234. Dataloading: 0.0035 s/iter. Inference: 0.1190 s/iter. Eval: 0.0002 s/iter. Total: 0.1229 s/iter. ETA=0:02:16
# [06/25 18:10:05 d2.evaluation.evaluator]: Inference done 1166/2234. Dataloading: 0.0034 s/iter. Inference: 0.1190 s/iter. Eval: 0.0002 s/iter. Total: 0.1229 s/iter. ETA=0:02:11
# [06/25 18:10:10 d2.evaluation.evaluator]: Inference done 1209/2234. Dataloading: 0.0034 s/iter. Inference: 0.1189 s/iter. Eval: 0.0002 s/iter. Total: 0.1227 s/iter. ETA=0:02:05
# [06/25 18:10:15 d2.evaluation.evaluator]: Inference done 1250/2234. Dataloading: 0.0034 s/iter. Inference: 0.1190 s/iter. Eval: 0.0002 s/iter. Total: 0.1227 s/iter. ETA=0:02:00
# [06/25 18:10:20 d2.evaluation.evaluator]: Inference done 1292/2234. Dataloading: 0.0034 s/iter. Inference: 0.1189 s/iter. Eval: 0.0002 s/iter. Total: 0.1227 s/iter. ETA=0:01:55
# [06/25 18:10:25 d2.evaluation.evaluator]: Inference done 1335/2234. Dataloading: 0.0033 s/iter. Inference: 0.1188 s/iter. Eval: 0.0002 s/iter. Total: 0.1225 s/iter. ETA=0:01:50
# [06/25 18:10:30 d2.evaluation.evaluator]: Inference done 1375/2234. Dataloading: 0.0033 s/iter. Inference: 0.1189 s/iter. Eval: 0.0002 s/iter. Total: 0.1226 s/iter. ETA=0:01:45
# [06/25 18:10:35 d2.evaluation.evaluator]: Inference done 1418/2234. Dataloading: 0.0033 s/iter. Inference: 0.1188 s/iter. Eval: 0.0002 s/iter. Total: 0.1225 s/iter. ETA=0:01:39
# [06/25 18:10:40 d2.evaluation.evaluator]: Inference done 1461/2234. Dataloading: 0.0033 s/iter. Inference: 0.1187 s/iter. Eval: 0.0002 s/iter. Total: 0.1224 s/iter. ETA=0:01:34
# [06/25 18:10:45 d2.evaluation.evaluator]: Inference done 1501/2234. Dataloading: 0.0033 s/iter. Inference: 0.1188 s/iter. Eval: 0.0002 s/iter. Total: 0.1225 s/iter. ETA=0:01:29
# [06/25 18:10:51 d2.evaluation.evaluator]: Inference done 1544/2234. Dataloading: 0.0033 s/iter. Inference: 0.1187 s/iter. Eval: 0.0002 s/iter. Total: 0.1224 s/iter. ETA=0:01:24
# [06/25 18:10:56 d2.evaluation.evaluator]: Inference done 1587/2234. Dataloading: 0.0032 s/iter. Inference: 0.1186 s/iter. Eval: 0.0002 s/iter. Total: 0.1222 s/iter. ETA=0:01:19
# [06/25 18:11:01 d2.evaluation.evaluator]: Inference done 1627/2234. Dataloading: 0.0032 s/iter. Inference: 0.1187 s/iter. Eval: 0.0002 s/iter. Total: 0.1223 s/iter. ETA=0:01:14
# [06/25 18:11:06 d2.evaluation.evaluator]: Inference done 1670/2234. Dataloading: 0.0032 s/iter. Inference: 0.1186 s/iter. Eval: 0.0002 s/iter. Total: 0.1222 s/iter. ETA=0:01:08
# [06/25 18:11:11 d2.evaluation.evaluator]: Inference done 1713/2234. Dataloading: 0.0032 s/iter. Inference: 0.1185 s/iter. Eval: 0.0002 s/iter. Total: 0.1221 s/iter. ETA=0:01:03
# [06/25 18:11:16 d2.evaluation.evaluator]: Inference done 1753/2234. Dataloading: 0.0032 s/iter. Inference: 0.1186 s/iter. Eval: 0.0002 s/iter. Total: 0.1222 s/iter. ETA=0:00:58
# [06/25 18:11:21 d2.evaluation.evaluator]: Inference done 1796/2234. Dataloading: 0.0032 s/iter. Inference: 0.1185 s/iter. Eval: 0.0002 s/iter. Total: 0.1221 s/iter. ETA=0:00:53
# [06/25 18:11:26 d2.evaluation.evaluator]: Inference done 1839/2234. Dataloading: 0.0032 s/iter. Inference: 0.1185 s/iter. Eval: 0.0002 s/iter. Total: 0.1220 s/iter. ETA=0:00:48
# [06/25 18:11:31 d2.evaluation.evaluator]: Inference done 1879/2234. Dataloading: 0.0032 s/iter. Inference: 0.1186 s/iter. Eval: 0.0002 s/iter. Total: 0.1221 s/iter. ETA=0:00:43
# [06/25 18:11:36 d2.evaluation.evaluator]: Inference done 1922/2234. Dataloading: 0.0032 s/iter. Inference: 0.1185 s/iter. Eval: 0.0002 s/iter. Total: 0.1220 s/iter. ETA=0:00:38
# [06/25 18:11:41 d2.evaluation.evaluator]: Inference done 1965/2234. Dataloading: 0.0031 s/iter. Inference: 0.1184 s/iter. Eval: 0.0002 s/iter. Total: 0.1219 s/iter. ETA=0:00:32
# [06/25 18:11:46 d2.evaluation.evaluator]: Inference done 2004/2234. Dataloading: 0.0032 s/iter. Inference: 0.1185 s/iter. Eval: 0.0002 s/iter. Total: 0.1221 s/iter. ETA=0:00:28
# [06/25 18:11:51 d2.evaluation.evaluator]: Inference done 2047/2234. Dataloading: 0.0032 s/iter. Inference: 0.1184 s/iter. Eval: 0.0002 s/iter. Total: 0.1220 s/iter. ETA=0:00:22
# [06/25 18:11:56 d2.evaluation.evaluator]: Inference done 2090/2234. Dataloading: 0.0031 s/iter. Inference: 0.1184 s/iter. Eval: 0.0002 s/iter. Total: 0.1219 s/iter. ETA=0:00:17
# [06/25 18:12:01 d2.evaluation.evaluator]: Inference done 2129/2234. Dataloading: 0.0032 s/iter. Inference: 0.1185 s/iter. Eval: 0.0002 s/iter. Total: 0.1220 s/iter. ETA=0:00:12
# [06/25 18:12:06 d2.evaluation.evaluator]: Inference done 2171/2234. Dataloading: 0.0032 s/iter. Inference: 0.1184 s/iter. Eval: 0.0002 s/iter. Total: 0.1220 s/iter. ETA=0:00:07
# [06/25 18:12:11 d2.evaluation.evaluator]: Inference done 2214/2234. Dataloading: 0.0032 s/iter. Inference: 0.1184 s/iter. Eval: 0.0002 s/iter. Total: 0.1219 s/iter. ETA=0:00:02
# [06/25 18:12:14 d2.evaluation.evaluator]: Total inference time: 0:04:31.939500 (0.122001 s / iter per device, on 1 devices)
# [06/25 18:12:14 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:23 (0.118381 s / iter per device, on 1 devices)
# [06/25 18:12:14 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [06/25 18:12:14 d2.evaluation.coco_evaluation]: Saving results to ./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/coco_instances_results.json
# [06/25 18:12:15 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [06/25 18:12:15 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [06/25 18:12:15 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.31 seconds.
# [06/25 18:12:15 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [06/25 18:12:15 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.858
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.388
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.483
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [06/25 18:12:15 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 33.339 | 85.792 | 15.038 | 32.582 | 38.898 |  nan  |
# [06/25 18:12:15 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# OrderedDict([('bbox', {'AP': 33.33884827374745, 'AP50': 85.79174934713248, 'AP75': 15.03823144894921, 'APs': 32.582349314574174, 'APm': 38.89803024379695, 'APl': nan})])

# %%
# test
evaluator = COCOEvaluator('ssdd_test', ('bbox',), False, output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test')

print(inference_on_dataset(trainer.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# [06/25 18:12:15 d2.evaluation.coco_evaluation]: Trying to convert 'ssdd_test' to COCO format ...
# WARNING [06/25 18:12:15 d2.data.datasets.coco]: Using previously cached COCO format annotations at './ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/ssdd_test_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [06/25 18:12:15 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ship    | 2378         |
# |            |              |
# [06/25 18:12:15 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/25 18:12:15 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:12:15 d2.data.common]: Serializing 3000 elements to byte tensors and concatenating them all ...
# [06/25 18:12:15 d2.data.common]: Serialized dataset takes 0.53 MiB
# [06/25 18:12:15 d2.evaluation.evaluator]: Start inference on 3000 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [06/25 18:12:17 d2.evaluation.evaluator]: Inference done 11/3000. Dataloading: 0.0017 s/iter. Inference: 0.1143 s/iter. Eval: 0.0001 s/iter. Total: 0.1161 s/iter. ETA=0:05:47
# [06/25 18:12:22 d2.evaluation.evaluator]: Inference done 54/3000. Dataloading: 0.0020 s/iter. Inference: 0.1151 s/iter. Eval: 0.0002 s/iter. Total: 0.1174 s/iter. ETA=0:05:45
# [06/25 18:12:27 d2.evaluation.evaluator]: Inference done 95/3000. Dataloading: 0.0026 s/iter. Inference: 0.1168 s/iter. Eval: 0.0002 s/iter. Total: 0.1197 s/iter. ETA=0:05:47
# [06/25 18:12:32 d2.evaluation.evaluator]: Inference done 136/3000. Dataloading: 0.0035 s/iter. Inference: 0.1171 s/iter. Eval: 0.0003 s/iter. Total: 0.1210 s/iter. ETA=0:05:46
# [06/25 18:12:37 d2.evaluation.evaluator]: Inference done 179/3000. Dataloading: 0.0031 s/iter. Inference: 0.1168 s/iter. Eval: 0.0002 s/iter. Total: 0.1203 s/iter. ETA=0:05:39
# [06/25 18:12:43 d2.evaluation.evaluator]: Inference done 221/3000. Dataloading: 0.0031 s/iter. Inference: 0.1171 s/iter. Eval: 0.0002 s/iter. Total: 0.1206 s/iter. ETA=0:05:35
# [06/25 18:12:48 d2.evaluation.evaluator]: Inference done 262/3000. Dataloading: 0.0031 s/iter. Inference: 0.1175 s/iter. Eval: 0.0002 s/iter. Total: 0.1209 s/iter. ETA=0:05:31
# [06/25 18:12:53 d2.evaluation.evaluator]: Inference done 305/3000. Dataloading: 0.0029 s/iter. Inference: 0.1172 s/iter. Eval: 0.0002 s/iter. Total: 0.1205 s/iter. ETA=0:05:24
# [06/25 18:12:58 d2.evaluation.evaluator]: Inference done 346/3000. Dataloading: 0.0029 s/iter. Inference: 0.1175 s/iter. Eval: 0.0002 s/iter. Total: 0.1207 s/iter. ETA=0:05:20
# [06/25 18:13:03 d2.evaluation.evaluator]: Inference done 387/3000. Dataloading: 0.0029 s/iter. Inference: 0.1177 s/iter. Eval: 0.0002 s/iter. Total: 0.1210 s/iter. ETA=0:05:16
# [06/25 18:13:08 d2.evaluation.evaluator]: Inference done 430/3000. Dataloading: 0.0028 s/iter. Inference: 0.1174 s/iter. Eval: 0.0002 s/iter. Total: 0.1206 s/iter. ETA=0:05:09
# [06/25 18:13:13 d2.evaluation.evaluator]: Inference done 471/3000. Dataloading: 0.0028 s/iter. Inference: 0.1176 s/iter. Eval: 0.0002 s/iter. Total: 0.1208 s/iter. ETA=0:05:05
# [06/25 18:13:18 d2.evaluation.evaluator]: Inference done 512/3000. Dataloading: 0.0029 s/iter. Inference: 0.1177 s/iter. Eval: 0.0002 s/iter. Total: 0.1209 s/iter. ETA=0:05:00
# [06/25 18:13:23 d2.evaluation.evaluator]: Inference done 555/3000. Dataloading: 0.0028 s/iter. Inference: 0.1175 s/iter. Eval: 0.0002 s/iter. Total: 0.1207 s/iter. ETA=0:04:55
# [06/25 18:13:28 d2.evaluation.evaluator]: Inference done 596/3000. Dataloading: 0.0028 s/iter. Inference: 0.1176 s/iter. Eval: 0.0002 s/iter. Total: 0.1208 s/iter. ETA=0:04:50
# [06/25 18:13:33 d2.evaluation.evaluator]: Inference done 637/3000. Dataloading: 0.0029 s/iter. Inference: 0.1177 s/iter. Eval: 0.0002 s/iter. Total: 0.1209 s/iter. ETA=0:04:45
# [06/25 18:13:38 d2.evaluation.evaluator]: Inference done 680/3000. Dataloading: 0.0028 s/iter. Inference: 0.1176 s/iter. Eval: 0.0002 s/iter. Total: 0.1208 s/iter. ETA=0:04:40
# [06/25 18:13:43 d2.evaluation.evaluator]: Inference done 722/3000. Dataloading: 0.0028 s/iter. Inference: 0.1177 s/iter. Eval: 0.0002 s/iter. Total: 0.1208 s/iter. ETA=0:04:35
# [06/25 18:13:48 d2.evaluation.evaluator]: Inference done 764/3000. Dataloading: 0.0028 s/iter. Inference: 0.1176 s/iter. Eval: 0.0002 s/iter. Total: 0.1209 s/iter. ETA=0:04:30
# [06/25 18:13:53 d2.evaluation.evaluator]: Inference done 807/3000. Dataloading: 0.0028 s/iter. Inference: 0.1175 s/iter. Eval: 0.0002 s/iter. Total: 0.
# [06/25 18:19:07 d2.evaluation.evaluator]: Inference done 405/766. Dataloading: 0.0027 s/iter. Inference: 0.1162 s/iter. Eval: 0.0002 s/iter. Total: 0.1193 s/iter. ETA=0:00:43
# [06/25 18:19:12 d2.evaluation.evaluator]: Inference done 446/766. Dataloading: 0.0029 s/iter. Inference: 0.1164 s/iter. Eval: 0.0002 s/iter. Total: 0.1195 s/iter. ETA=0:00:38
# [06/25 18:19:17 d2.evaluation.evaluator]: Inference done 488/766. Dataloading: 0.0028 s/iter. Inference: 0.1164 s/iter. Eval: 0.0002 s/iter. Total: 0.1196 s/iter. ETA=0:00:33
# [06/25 18:19:22 d2.evaluation.evaluator]: Inference done 531/766. Dataloading: 0.0028 s/iter. Inference: 0.1162 s/iter. Eval: 0.0002 s/iter. Total: 0.1193 s/iter. ETA=0:00:28
# [06/25 18:19:27 d2.evaluation.evaluator]: Inference done 572/766. Dataloading: 0.0028 s/iter. Inference: 0.1165 s/iter. Eval: 0.0002 s/iter. Total: 0.1196 s/iter. ETA=0:00:23
# [06/25 18:19:32 d2.evaluation.evaluator]: Inference done 615/766. Dataloading: 0.0027 s/iter. Inference: 0.1165 s/iter. Eval: 0.0002 s/iter. Total: 0.1196 s/iter. ETA=0:00:18
# [06/25 18:19:37 d2.evaluation.evaluator]: Inference done 659/766. Dataloading: 0.0027 s/iter. Inference: 0.1163 s/iter. Eval: 0.0002 s/iter. Total: 0.1193 s/iter. ETA=0:00:12
# [06/25 18:19:42 d2.evaluation.evaluator]: Inference done 700/766. Dataloading: 0.0028 s/iter. Inference: 0.1165 s/iter. Eval: 0.0002 s/iter. Total: 0.1195 s/iter. ETA=0:00:07
# [06/25 18:19:47 d2.evaluation.evaluator]: Inference done 742/766. Dataloading: 0.0027 s/iter. Inference: 0.1165 s/iter. Eval: 0.0002 s/iter. Total: 0.1196 s/iter. ETA=0:00:02
# [06/25 18:19:50 d2.evaluation.evaluator]: Total inference time: 0:01:31.088875 (0.119696 s / iter per device, on 1 devices)
# [06/25 18:19:50 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:28 (0.116476 s / iter per device, on 1 devices)
# [06/25 18:19:50 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [06/25 18:19:50 d2.evaluation.coco_evaluation]: Saving results to ./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/coco_instances_results.json
# [06/25 18:19:50 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [06/25 18:19:50 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [06/25 18:19:50 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.17 seconds.
# [06/25 18:19:50 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [06/25 18:19:50 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.040
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# [06/25 18:19:50 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl  |
# |:------:|:------:|:------:|:------:|:------:|:-----:|
# | 13.338 | 36.444 | 5.092  | 12.827 | 40.063 |  nan  |
# [06/25 18:19:50 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# OrderedDict([('bbox', {'AP': 13.33816285887842, 'AP50': 36.444498319921784, 'AP75': 5.091931300289467, 'APs': 12.82655750939826, 'APm': 40.062790632610174, 'APl': nan})])

# %%
# %ls ./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO
# Out:
# coco_instances_results.json
# events.out.tfevents.1687603336.5f94d9f2bd8e.401.0
# events.out.tfevents.1687618225.5f94d9f2bd8e.65011.0
# instances_predictions.pth
# last_checkpoint
# metrics.json
# model_0004999.pth
# model_0009999.pth
# model_0014999.pth
# model_0019999.pth
# model_0024999.pth
# model_0029999.pth
# model_final.pth
# predImages/
# predImages_eval/
# ssdd_test_coco_format.json
# ssdd_test_coco_format.json.lock
# ssdd_test_inshore_coco_format.json
# ssdd_test_inshore_coco_format.json.lock
# ssdd_test_offshore_coco_format.json
# ssdd_test_offshore_coco_format.json.lock
# Validation_eval/

# %% [markdown]
# # Evaluation using a Custom Evaluator
#
# detectron2.evaluation.coco_evaluation: https://detectron2.readthedocs.io/en/latest/_modules/detectron2/evaluation/coco_evaluation.html
#
# detectron2.evaluation: https://detectron2.readthedocs.io/en/latest/modules/evaluation.html#
#
# Evaluation: https://detectron2.readthedocs.io/en/latest/tutorials/evaluation.html
#
# Evaluation:
#
# https://github.com/facebookresearch/detectron2/blob/master/detectron2/evaluation/coco_evaluation.py
# https://github.com/facebookresearch/Detectron/blob/a6a835f5b8208c45d0dce217ce9bbda915f44df7/detectron/datasets/json_dataset_evaluator.py
#
# Concept:
#
# https://cs230.stanford.edu/section/7/
#
# https://jonathan-hui.medium.com/map-mean-average-precision-for-object-detection-45c121a31173

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from detectron2.structures import Boxes, BoxMode, pairwise_iou
from detectron2.data.datasets.coco import convert_to_coco_json
from detectron2.evaluation import DatasetEvaluator
from detectron2.utils.file_io import PathManager
from collections import OrderedDict
from pycocotools.coco import COCO
import itertools
import contextlib
import torch
import copy
import os
import io

# %%
def average_precision(correct, ground_truth):
  # correct contains True Positives (TP) and False Positives (FP)
  # ground_truth is the number of positive examples (TP + FN = GT)

  # precision = TP / (TP + FP)
  # recall = TP / (TP + FN) = TP / GT
  TP = 0
  FP = 0
  GT = ground_truth
  precision = []
  recall = []

  for i, c in enumerate(correct):
    if c:
      TP += 1
    else:
      FP += 1
    precision.append(TP / (TP + FP))
    if GT == 0:
      recall.append(0.0)
    else:
      recall.append(TP / GT)


  # Interpolate precision (replace each precision value with the maximum precision value to the right of that recall level)
  max = 0
  precision_interp = []

  for i, c in enumerate(reversed(precision)):
    if c > max:
      max = c
      precision_interp.append(c)
    else:
      precision_interp.append(max)

  precision_interp = list(reversed(precision_interp))


  # Calculate AP (Average Precision)
  AP = 0
  for i, c in enumerate(recall):
    if i == 0:
      continue
    AP += (recall[i] - recall[i-1]) * precision_interp[i]

  return recall, precision_interp, AP


# Test Case
#test = [True, True, False, False, False, True, True, False, False, True]
#recall, precision, AP = average_precision(test, 5)
#assert AP == 0.5285714285714286
#assert recall == [0.2, 0.4, 0.4, 0.4, 0.4, 0.6, 0.8, 0.8, 0.8, 1.0]
#assert precision == [1.0,
#                    1.0,
#                    0.6666666666666666,
#                    0.5714285714285714,
#                    0.5714285714285714,
#                    0.5714285714285714,
#                    0.5714285714285714,
#                    0.5,
#                    0.5,
#                    0.5]

# %%
class CustomEvaluator(DatasetEvaluator):
  def __init__(
        self,
        dataset_name,
        output_dir
  ):
    """
    Args:
        dataset_name (str): name of the dataset to be evaluated.
            It must have either the following corresponding metadata:

                "json_file": the path to the COCO format annotation

            Or it must be in detectron2's standard dataset format
            so it can be converted to COCO format automatically.
        output_dir (str): an output directory to dump all
            results predicted on the dataset. The dump contains two files:

            1. "instances_predictions.pth" (dataset_name + "_predictions.pth")
                a file that can be loaded with `torch.load` and
                contains all the results in the format they are produced by the model.
            2. "coco_instances_results.json" a json file in COCO's result format.
    """
    self._cpu_device = torch.device("cpu")
    self.dataset_name = dataset_name
    self._metadata = MetadataCatalog.get(dataset_name)
    self._output_dir = output_dir

    if not hasattr(self._metadata, "json_file"):
      cache_path = os.path.join(output_dir, f"{dataset_name}_coco_format.json")
      self._metadata.json_file = cache_path
      convert_to_coco_json(dataset_name, cache_path)

    json_file = PathManager.get_local_path(self._metadata.json_file)
    with contextlib.redirect_stdout(io.StringIO()):
        self._coco_api = COCO(json_file)

  def reset(self):
    """
    Preparation for a new round of evaluation.
    """
    self._predictions = []

  def process(self, inputs, outputs):
    """
    Process the pair of inputs and outputs.

    Args:
        inputs: the inputs to a COCO model (e.g., GeneralizedRCNN).
            It is a list of dict. Each dict corresponds to an image and
            contains keys like "height", "width", "file_name", "image_id".
        outputs: the outputs of a COCO model. It is a list of dicts with key
            "instances" that contains :class:`Instances`.
    """
    for input, output in zip(inputs, outputs):
      prediction = {"image_id": input["image_id"]}
      if "instances" in output:
          prediction["instances"] = output["instances"].to(self._cpu_device)
      if len(prediction) > 1:
          self._predictions.append(prediction)

    if self._output_dir:
      PathManager.mkdirs(self._output_dir)
      file_path = os.path.join(self._output_dir,
                               self.dataset_name + "_predictions.pth")
#      file_path = os.path.join(self._output_dir, "instances_predictions.pth")
#      file_path = os.path.join(self._output_dir, f"{dataset_name}_predictions.pth") # NameError: name 'dataset_name' is not defined

      with PathManager.open(file_path, "wb") as f:
        torch.save(self._predictions, f)

  def evaluate(self):
    """
    Evaluate/summarize the performance, after processing all input/output pairs.
    Evaluates on the whole dataset.
    """
    iou_threshold = 0.5
    num_instances = 0
    num_pos = 0  # must be equal to GT
    gt_overlaps = []
#    ap = []
    scores = []
    correct = []
    bad_images = []

    if len(self._predictions) == 0:
      return {}, {}, {}

    # Loop over all instances in one image
    for prediction_dict in self._predictions:
      predictions = prediction_dict["instances"]
      num_instances += len(predictions)

      # Get scores of each instance, sort in descending order
      inds = predictions.get_fields()['scores'].sort(descending=True)[1]
      in_scores = predictions.get_fields()['scores']
      in_scores = in_scores[inds]

      # Get bbox of each instance, sort by score
      in_boxes = predictions.get_fields()['pred_boxes']
      in_boxes = in_boxes[inds]

      assert len(in_boxes) == len(in_scores) == len(predictions)

      # Retrieve corresponding ground truth boxes/labels
      ann_ids = self._coco_api.getAnnIds(imgIds=[prediction_dict["image_id"]])
      anno = self._coco_api.loadAnns(ann_ids)
      gt_boxes = [
          BoxMode.convert(obj["bbox"], BoxMode.XYWH_ABS, BoxMode.XYXY_ABS)
          for obj in anno
          if obj["iscrowd"] == 0
      ]
      gt_boxes = torch.as_tensor(gt_boxes).reshape(-1, 4)
      gt_boxes = Boxes(gt_boxes)

#      if len(predictions) == 0 or len(gt_boxes) == 0:
#        continue

      num_pos += len(gt_boxes)

      # Compute IOU for each instance-ground truth pair
      overlaps = pairwise_iou(in_boxes, gt_boxes)

      _gt_overlaps = torch.zeros(len(gt_boxes)) # stores iou for each gt box in one image
      _scores = torch.zeros(len(in_scores)) # stores iou for each proposal box (score) in one image

      # Ensure 1-1 mapping between prediction and gt boxes
      for j in range(min(len(predictions), len(gt_boxes))):
          # find which proposal box maximally covers each gt box
          # and get the iou amount of coverage for each gt box
          max_overlaps, argmax_overlaps = overlaps.max(dim=0)

          # find which gt box is 'best' covered (i.e. 'best' = most iou)
          gt_ovr, gt_ind = max_overlaps.max(dim=0)
          assert gt_ovr >= 0

          # find the proposal box that covers the best covered gt box
          box_ind = argmax_overlaps[gt_ind]

          # record the iou coverage of this gt box
          _gt_overlaps[j] = overlaps[box_ind, gt_ind]  # _gt_overlaps[gt_ind] ?
          assert _gt_overlaps[j] == gt_ovr  # _gt_overlaps[gt_ind] ?

          # record this iou coverage for score
          _scores[box_ind] = overlaps[box_ind, gt_ind]
          assert _scores[box_ind] == gt_ovr

          # mark the proposal box and the gt box as used
          overlaps[box_ind, :] = -1
          overlaps[:, gt_ind] = -1

      # update collectors
      _correct = (_scores >= iou_threshold).tolist() # stores TP/FP for each proposal box in one image

      assert len(_correct) == len(_scores) == len(predictions)

      if _correct and sum(np.invert(_correct)) > 0:
        bad_images.append(prediction_dict)

#      _, __, _ap = average_precision(_correct, len(gt_boxes))

      # append recorded iou coverage level
      gt_overlaps.append(_gt_overlaps)
      scores.append(in_scores)
      correct.append(_correct)
#      ap.append(_ap)


    # all images
    gt_overlaps = (
        torch.cat(gt_overlaps, dim=0) if len(gt_overlaps)
         else torch.zeros(0, dtype=torch.float32)
    )
    gt_overlaps, _ = torch.sort(gt_overlaps, descending = True)

    scores = (
        torch.cat(scores, dim=0) if len(scores)
         else torch.zeros(0, dtype=torch.float32)
    )
    scores, ind = torch.sort(scores, descending = True)

    # stores TP/FP for each proposal box in all images (in descending order of scores)
    correct = list(itertools.chain.from_iterable(correct))
    assert len(scores) == len(correct)
    correct = [correct[i] for i in ind.tolist()]

    # The following metrics are computed at iou_threshold
    GT = len(self._coco_api.getAnnIds())
    assert GT == num_pos

    TP = np.sum(np.array(correct))
    FP = len(correct) - TP
    assert (TP + FP) == num_instances
    FN = GT - TP

    Pd = TP / GT          # Detection probability
    Pf = FP / (TP + FP)   # false alarm
    Pm = FN / GT          # missed detection
    # assert (Pd + Pm) == 1

    recall = TP / (TP + FN)
    precision = TP / (TP + FP)
    F1 = 2 * (precision * recall) / (precision + recall)
#    meanAP = np.array(ap).mean()
    recalls, precisions, mAP = average_precision(correct, GT)

    plot = {"recalls": recalls, "precisions": precisions}
    hist = {"gt_overlap": gt_overlaps, "scores": scores}
    self._results = {
        "TP": TP,
        "FP": FP,
        "GT": GT,
        "FN": FN,
        "Pd": Pd,
        "Pf": Pf,
        "Pm": Pm,
        "recall": recall,
        "precision": precision,
        "mAP": mAP,
        "F1": F1
    }

    return copy.deepcopy(self._results), plot, hist, bad_images

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

#val = './datasets/test/'

# %%
# test_inshore
custEval = CustomEvaluator('ssdd_test_inshore', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_inshore')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [06/25 18:19:50 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/25 18:19:50 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:19:50 d2.data.common]: Serializing 766 elements to byte tensors and concatenating them all ...
# [06/25 18:19:50 d2.data.common]: Serialized dataset takes 0.14 MiB
# [06/25 18:19:50 d2.evaluation.evaluator]: Start inference on 766 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
# [06/25 18:21:08 d2.evaluation.evaluator]: Inference done 503/766. Dataloading: 0.0030 s/iter. Inference: 0.1087 s/iter. Eval: 0.0426 s/iter. Total: 0.1546 s/iter. ETA=0:00:40
# [06/25 18:21:13 d2.evaluation.evaluator]: Inference done 527/766. Dataloading: 0.0032 s/iter. Inference: 0.1088 s/iter. Eval: 0.0450 s/iter. Total: 0.1571 s/iter. ETA=0:00:37
# [06/25 18:21:19 d2.evaluation.evaluator]: Inference done 556/766. Dataloading: 0.0031 s/iter. Inference: 0.1086 s/iter. Eval: 0.0462 s/iter. Total: 0.1581 s/iter. ETA=0:00:33
# [06/25 18:21:24 d2.evaluation.evaluator]: Inference done 583/766. Dataloading: 0.0030 s/iter. Inference: 0.1087 s/iter. Eval: 0.0478 s/iter. Total: 0.1597 s/iter. ETA=0:00:29
# [06/25 18:21:29 d2.evaluation.evaluator]: Inference done 606/766. Dataloading: 0.0031 s/iter. Inference: 0.1087 s/iter. Eval: 0.0500 s/iter. Total: 0.1620 s/iter. ETA=0:00:25
# [06/25 18:21:34 d2.evaluation.evaluator]: Inference done 633/766. Dataloading: 0.0030 s/iter. Inference: 0.1086 s/iter. Eval: 0.0514 s/iter. Total: 0.1632 s/iter. ETA=0:00:21
# [06/25 18:21:39 d2.evaluation.evaluator]: Inference done 656/766. Dataloading: 0.0030 s/iter. Inference: 0.1086 s/iter. Eval: 0.0534 s/iter. Total: 0.1652 s/iter. ETA=0:00:18
# [06/25 18:21:44 d2.evaluation.evaluator]: Inference done 679/766. Dataloading: 0.0030 s/iter. Inference: 0.1086 s/iter. Eval: 0.0556 s/iter. Total: 0.1674 s/iter. ETA=0:00:14
# [06/25 18:21:49 d2.evaluation.evaluator]: Inference done 705/766. Dataloading: 0.0030 s/iter. Inference: 0.1085 s/iter. Eval: 0.0570 s/iter. Total: 0.1686 s/iter. ETA=0:00:10
# [06/25 18:21:54 d2.evaluation.evaluator]: Inference done 726/766. Dataloading: 0.0030 s/iter. Inference: 0.1085 s/iter. Eval: 0.0589 s/iter. Total: 0.1707 s/iter. ETA=0:00:06
# [06/25 18:22:00 d2.evaluation.evaluator]: Inference done 748/766. Dataloading: 0.0031 s/iter. Inference: 0.1084 s/iter. Eval: 0.0607 s/iter. Total: 0.1724 s/iter. ETA=0:00:03
# [06/25 18:22:03 d2.evaluation.evaluator]: Total inference time: 0:02:12.034271 (0.173501 s / iter per device, on 1 devices)
# [06/25 18:22:03 d2.evaluation.evaluator]: Total inference pure compute time: 0:01:22 (0.108356 s / iter per device, on 1 devices)

# %%
eval, plot, hist, bad_images = custEval.evaluate()
eval
# Out:
# {'TP': 365,
#  'FP': 207,
#  'GT': 883,
#  'FN': 518,
#  'Pd': 0.41336353340883353,
#  'Pf': 0.3618881118881119,
#  'Pm': 0.5866364665911665,
#  'recall': 0.41336353340883353,
#  'precision': 0.6381118881118881,
#  'mAP': 0.36017366020076186,
#  'F1': 0.5017182130584193}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %%
# test_offshore
custEval = CustomEvaluator('ssdd_test_offshore', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test_offshore')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [06/25 18:22:05 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/25 18:22:05 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:22:05 d2.data.common]: Serializing 2234 elements to byte tensors and concatenating them all ...
# [06/25 18:22:05 d2.data.common]: Serialized dataset takes 0.41 MiB
# [06/25 18:22:05 d2.evaluation.evaluator]: Start inference on 2234 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [06/25 18:22:07 d2.evaluation.evaluator]: Inference done 11/2234. Dataloading: 0.0030 s/iter. Inference: 0.1198 s/iter. Eval: 0.0074 s/iter. Total: 0.1303 s/iter. ETA=0:04:49
# [06/25 18:22:12 d2.evaluation.evaluator]: Inference done 50/2234. Dataloading: 0.0056 s/iter. Inference: 0.1147 s/iter. Eval: 0.0103 s/iter. Total: 0.1308 s/iter. ETA=0:04:45
# [06/25 18:22:17 d2.evaluation.evaluator]: Inference done 90/2234. Dataloading: 0.0038 s/iter. Inference: 0.1120 s/iter. Eval: 0.0124 s/iter. Total: 0.1284 s/iter. ETA=0:04:35
# [06/25 18:22:22 d2.evaluation.evaluator]: Inference done 127/2234. Dataloading: 0.0036 s/iter. Inference: 0.1116 s/iter. Eval: 0.0150 s/iter. Total: 0.1305 s/iter. ETA=0:04:34
# [06/25 18:22:27 d2.evaluation.evaluator]: Inference done 162/2234. Dataloading: 0.0036 s/iter. Inference: 0.1119 s/iter. Eval: 0.0181 s/iter. Total: 0.1340 s/iter. ETA=0:04:37
# [06/25 18:22:32 d2.evaluation.evaluator]: Inference done 199/2234. Dataloading: 0.0033 s/iter. Inference: 0.1112 s/iter. Eval: 0.0198 s/iter. Total: 0.1346 s/iter. ETA=0:04:33
# [06/25 18:22:37 d2.evaluation.evaluator]: Inference done 232/2234. Dataloading: 0.0032 s/iter. Inference: 0.1112 s/iter. Eval: 0.0225 s/iter. Total: 0.1373 s/iter. ETA=0:04:34
# [06/25 18:22:42 d2.evaluation.evaluator]: Inference done 263/2234. Dataloading: 0.0032 s/iter. Inference: 0.1111 s/iter. Eval: 0.0257 s/iter. Total: 0.1403 s/iter. ETA=0:04:36
# [06/25 18:22:47 d2.evaluation.evaluator]: Inference done 298/2234. Dataloading: 0.0031 s/iter. Inference: 0.1106 s/iter. Eval: 0.0272 s/iter. Total: 0.1411 s/iter. ETA=0:04:33
# [06/25 18:22:53 d2.evaluation.evaluator]: Inference done 328/2234. Dataloading: 0.0032 s/iter. Inference: 0.1105 s/iter. Eval: 0.0301 s/iter. Total: 0.1440 s/iter. ETA=0:04:34
# [06/25 18:22:58 d2.evaluation.evaluator]: Inference done 358/2234. Dataloading: 0.0032 s/iter. Inference: 0.1104 s/iter. Eval: 0.0322 s/iter. Total: 0.1460 s/iter. ETA=0:04:33
# [06/25 18:23:03 d2.evaluation.evaluator]: Inference done 390/2234. Dataloading: 0.0031 s/iter. Inference: 0.1100 s/iter. Eval: 0.0339 s/iter. Total: 0.1472 s/iter. ETA=0:04:31
# [06/25 18:23:08 d2.evaluation.evaluator]: Inference done 417/2234. Dataloading: 0.0032 s/iter. Inference: 0.1100 s/iter. Eval: 0.0365 s/iter. Total: 0.1500 s/iter. ETA=0:04:32
# [06/25 18:23:13 d2.evaluation.evaluator]: Inference done 446/2234. Dataloading: 0.0032 s/iter. Inference: 0.1098 s/iter. Eval: 0.0383 s/iter. Total: 0.1515 s/iter. ETA=0:04:30
# [06/25 18:23:18 d2.evaluation.evaluator]: Inference done 476/2234. Dataloading: 0.0031 s/iter. Inference: 0.1095 s/iter. Eval: 0.0398 s/iter. Total: 0.1527 s/iter. ETA=0:04:28
2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1698 s/iter. Total: 0.2817 s/iter. ETA=0:00:23
# [06/25 18:32:15 d2.evaluation.evaluator]: Inference done 2162/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1705 s/iter. Total: 0.2824 s/iter. ETA=0:00:20
# [06/25 18:32:20 d2.evaluation.evaluator]: Inference done 2171/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1716 s/iter. Total: 0.2836 s/iter. ETA=0:00:17
# [06/25 18:32:26 d2.evaluation.evaluator]: Inference done 2184/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1724 s/iter. Total: 0.2843 s/iter. ETA=0:00:14
# [06/25 18:32:31 d2.evaluation.evaluator]: Inference done 2196/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1732 s/iter. Total: 0.2851 s/iter. ETA=0:00:10
# [06/25 18:32:36 d2.evaluation.evaluator]: Inference done 2206/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1743 s/iter. Total: 0.2863 s/iter. ETA=0:00:08
# [06/25 18:32:41 d2.evaluation.evaluator]: Inference done 2219/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1751 s/iter. Total: 0.2870 s/iter. ETA=0:00:04
# [06/25 18:32:47 d2.evaluation.evaluator]: Inference done 2230/2234. Dataloading: 0.0033 s/iter. Inference: 0.1082 s/iter. Eval: 0.1761 s/iter. Total: 0.2880 s/iter. ETA=0:00:01
# [06/25 18:32:49 d2.evaluation.evaluator]: Total inference time: 0:10:43.162130 (0.288543 s / iter per device, on 1 devices)
# [06/25 18:32:49 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:01 (0.108211 s / iter per device, on 1 devices)

# %%
eval, plot, hist, bad_images = custEval.evaluate()
eval
# Out:
# {'TP': 1317,
#  'FP': 193,
#  'GT': 1495,
#  'FN': 178,
#  'Pd': 0.8809364548494983,
#  'Pf': 0.12781456953642384,
#  'Pm': 0.11906354515050167,
#  'recall': 0.8809364548494983,
#  'precision': 0.8721854304635761,
#  'mAP': 0.8572489221822152,
#  'F1': 0.8765391014975041}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %%
# test
custEval = CustomEvaluator('ssdd_test', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_test')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [06/25 18:32:52 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/25 18:32:52 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:32:52 d2.data.common]: Serializing 3000 elements to byte tensors and concatenating them all ...
# [06/25 18:32:52 d2.data.common]: Serialized dataset takes 0.53 MiB
# [06/25 18:32:52 d2.evaluation.evaluator]: Start inference on 3000 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [06/25 18:32:54 d2.evaluation.evaluator]: Inference done 11/3000. Dataloading: 0.0016 s/iter. Inference: 0.1117 s/iter. Eval: 0.0104 s/iter. Total: 0.1237 s/iter. ETA=0:06:09
# [06/25 18:32:59 d2.evaluation.evaluator]: Inference done 52/3000. Dataloading: 0.0018 s/iter. Inference: 0.1109 s/iter. Eval: 0.0093 s/iter. Total: 0.1223 s/iter. ETA=0:06:00
# [06/25 18:33:04 d2.evaluation.evaluator]: Inference done 88/3000. Dataloading: 0.0035 s/iter. Inference: 0.1126 s/iter. Eval: 0.0139 s/iter. Total: 0.1303 s/iter. ETA=0:06:19
# [06/25 18:33:09 d2.evaluation.evaluator]: Inference done 127/3000. Dataloading: 0.0030 s/iter. Inference: 0.1118 s/iter. Eval: 0.0156 s/iter. Total: 0.1307 s/iter. ETA=0:06:15
# [06/25 18:33:14 d2.evaluation.evaluator]: Inference done 164/3000. Dataloading: 0.0027 s/iter. Inference: 0.1116 s/iter. Eval: 0.0176 s/iter. Total: 0.1322 s/iter. ETA=0:06:14
# [06/25 18:34:35 d2.evaluation.evaluator]: Inference done 624/3000. Dataloading: 0.0029 s/iter. Inference: 0.1094 s/iter. Eval: 0.0527 s/iter. Total: 0.1652 s/iter. ETA=0:06:32
# [06/25 18:34:40 d2.evaluation.evaluator]: Inference done 650/3000. Dataloading: 0.0029 s/iter. Inference: 0.1093 s/iter. Eval: 0.0542 s/iter. Total: 0.1666 s/iter. ETA=0:06:31
# [06/25 18:34:46 d2.evaluation.evaluator]: Inference done 671/3000. Dataloading: 0.0030 s/iter. Inference: 0.1093 s/iter. Eval: 0.0567 s/iter. Total: 0.1692 s/iter. ETA=0:06:33
# [06/25 18:34:51 d2.evaluation.evaluator]: Inference done 695/3000. Dataloading: 0.0029 s/iter. Inference: 0.1092 s/iter. Eval: 0.0582 s/iter. Total: 0.1706 s/iter. ETA=0:06:33
# [06/25 18:34:56 d2.evaluation.evaluator]: Inference done 719/3000. Dataloading: 0.0029 s/iter. Inference: 0.1092 s/iter. Eval: 0.0598 s/iter. Total: 0.1721 s/iter. ETA=0:06:32
# [06/25 18:35:01 d2.evaluation.evaluator]: Inference done 738/3000. Dataloading: 0.0030 s/iter. Inference: 0.1093 s/iter. Eval: 0.0623 s/iter. Total: 0.1748 s/iter. ETA=0:06:35
# [06/25 18:35:06 d2.evaluation.evaluator]: Inference done 762/3000. Dataloading: 0.0030 s/iter. Inference: 0.1092 s/iter. Eval: 0.0636 s/iter. Total: 0.1759 s/iter. ETA=0:06:33
# [06/25 18:35:11 d2.evaluation.evaluator]: Inference done 785/3000. Dataloading: 0.0029 s/iter. Inference: 0.1091 s/iter. Eval: 0.0650 s/iter. Total: 0.1772 s/iter. ETA=0:06:32
# [06/25 18:35:16 d2.evaluation.evaluator]: Inference done 803/3000. Dataloading: 0.0030 s/iter. Inference: 0.1092 s/iter. Eval: 0.0672 s/iter. Total: 0.1796 s/iter. ETA=0:06:34
# [06/25 18:35:21 d2.evaluation.evaluator]: Inference done 826/3000. Dataloading: 0.0029 s/iter. Inference: 0.1091 s/iter. Eval: 0.0686 s/iter. Total: 0.1808 s/iter. ETA=0:06:33
# [06/25 18:35:27 d2.evaluation.evaluator]: Inference done 847/3000. Dataloading: 0.0029 s/iter. Inference: 0.1090 s/iter. Eval: 0.0703 s/iter. Total: 0.1824 s/iter. ETA=0:06:32
# [06/25 18:35:32 d2.evaluation.evaluator]: Inference done 866/3000. Dataloading: 0.0029 s/iter. Inference: 0.1091 s/iter. Eval: 0.0722 s/iter. Total: 0.1844 s/iter. ETA=0:06:33
# [06/25 18:35:37 d2.evaluation.evaluator]: Inference done 888/3000. Dataloading: 0.0029 s/iter. Inference: 0.1091 s/iter. Eval: 0.0734 s/iter. Total: 0.1856 s/iter. ETA=0:06:31
# [06/25 18:35:42 d2.evaluation.evaluator]: Inference done 907/3000. Dataloading: 0.0029 s/iter. Inference: 0.1090 s/iter. Eval: 0.0752 s/iter. Total: 0.1873 s/iter. ETA=0:06:31
# [06/25 18:35:47 d2.evaluation.evaluator]: Inference done 925/3000. Dataloading: 0.0029 s/iter. Inference: 0.1091 s/iter. Eval: 0.0770 s/iter. Total: 0.1891 s/iter. ETA=0:06:32
# [06/25 18:35:52 d2.evaluation.evaluator]: Inference done 946/3000. Dataloading: 0.0029 s/iter. Inference: 0.1090 s/iter. Eval: 0.0781 s/iter. Total: 0.1903 s/iter. ETA=0:06:30
# [06/25 18:35:57 d2.evaluation.evaluator]: Inference done 964/3000. Dataloading: 0.0029 s/iter. Inference: 0.1090 s/iter. Eval: 0.0798 s/iter. Total: 0.1919 s/iter. ETA=0:06:30
# [06/25 18:36:02 d2.evaluation.evaluator]: Inference done 982/3000. Dataloading: 0.0029 s/iter. Inference: 0.1091 s/iter. Eval: 0.0814 s/iter. Total: 0.1936 s/iter. ETA=0:06:30
# [06/25 18:36:07 d2.evaluation.evaluator]: Inference done 1003/3000. Dataloading: 0.0029 s/iter. Inference: 0.1090 s/iter. Eval: 0.0826 s/iter. Total: 0.1947 s/iter. ETA=0:06:28
# [06/25 18:36:13 d2.evaluation.evaluator]: Inference done 1020/3000. Dataloading: 0.0030 s/iter. Inference: 0.1090 s/iter. Eval: 0.0844 s/iter. Total: 0.1966 s/iter. ETA=0:06:29
# [06/25 18:36:18 d2.evaluation.evaluator]: Inference done 1039/3000. Dataloading: 0.0030 s/iter. Inference: 0.1090 s/iter. Eval: 0.0857 s/iter. Total: 0.1979 s/iter. ETA=0:06:28
# [06/25 18:36:23 d2.evaluation.evaluator]: Inference done 1059/3000. Dataloading: 0.0030 s/iter. Inference: 0.1089 s/iter. Eval: 0.0869 s/iter. Total: 0.1991 s/iter. ETA=0:06:26
# [06/25 18:36:28 d2.evaluation.evaluator]: Inference done 1074/3000. Dataloading: 0.0030 s/iter. Inference: 0.1090 s/iter. Eval: 0.0888 s/iter. Total: 0.2010 s/iter. ETA=0:06:27
# [06/25 18:36:33 d2.evaluation.evaluator]: Inference done 1094/3000. Dataloading: 0.0030 s/iter. Inference: 0.1089 s/iter. Eval: 0.0899 s/iter. Total: 0.2021 s/iter. ETA=0:06:25
# [06/25 18:36:39 d2.evaluation.evaluator]: Inference done 1114/3000. Dataloading: 0.0030 s/iter. Inference: 0.1089 s/iter. Eval: 0.0912 s/iter. Total: 0.2034 s/iter. ETA=0:06:23
# [06/25 18:36:44 d2.evaluation.evaluator]: Inference done 1129/3000. Dataloading: 0.0031 s/iter. Inference: 0.1090 s/iter. Eval: 0.0929 s/iter. Total: 0.2052 s/iter. ETA=0:06:23
# [06/25 18:36:49 d2.evaluation.evaluator]: Inference done 1148/3000. Dataloading: 0.0030 s/iter. Inference: 0.1089 s/iter. Eval: 0.0941 s/iter. Total: 0.2063 s/iter. ETA=0:06:22
# [06/25 18:36:54 d2.evaluation.evaluator]: Inference done 1166/3000. Dataloading: 0.0030 s/iter. Inference: 0.1089 s/iter. Eval: 0.0953 s/iter. Total: 0.2075 s/iter. ETA=0:06:20
# [06/25 18:36:59 d2.evaluation.evaluator]: Inference done 1181/3000. Dataloading: 0.0031 s/iter. Inference: 0.1089 s/iter. Eval: 0.0970 s/iter. Total: 0.2093 s/iter. ETA=0:06:20
3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2350 s/iter. Total: 0.3474 s/iter. ETA=0:00:25
# [06/25 18:49:53 d2.evaluation.evaluator]: Inference done 2937/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2356 s/iter. Total: 0.3480 s/iter. ETA=0:00:21
# [06/25 18:49:59 d2.evaluation.evaluator]: Inference done 2944/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2365 s/iter. Total: 0.3489 s/iter. ETA=0:00:19
# [06/25 18:50:04 d2.evaluation.evaluator]: Inference done 2954/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2371 s/iter. Total: 0.3494 s/iter. ETA=0:00:16
# [06/25 18:50:09 d2.evaluation.evaluator]: Inference done 2964/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2378 s/iter. Total: 0.3502 s/iter. ETA=0:00:12
# [06/25 18:50:15 d2.evaluation.evaluator]: Inference done 2972/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2387 s/iter. Total: 0.3511 s/iter. ETA=0:00:09
# [06/25 18:50:20 d2.evaluation.evaluator]: Inference done 2982/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2393 s/iter. Total: 0.3517 s/iter. ETA=0:00:06
# [06/25 18:50:26 d2.evaluation.evaluator]: Inference done 2991/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2401 s/iter. Total: 0.3525 s/iter. ETA=0:00:03
# [06/25 18:50:31 d2.evaluation.evaluator]: Inference done 3000/3000. Dataloading: 0.0034 s/iter. Inference: 0.1085 s/iter. Eval: 0.2408 s/iter. Total: 0.3532 s/iter. ETA=0:00:00
# [06/25 18:50:31 d2.evaluation.evaluator]: Total inference time: 0:17:38.082058 (0.353283 s / iter per device, on 1 devices)
# [06/25 18:50:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:05:24 (0.108511 s / iter per device, on 1 devices)

# %%
eval, plot, hist, bad_images = custEval.evaluate()
eval
# Out:
# {'TP': 1682,
#  'FP': 400,
#  'GT': 2378,
#  'FN': 696,
#  'Pd': 0.7073170731707317,
#  'Pf': 0.19212295869356388,
#  'Pm': 0.2926829268292683,
#  'recall': 0.7073170731707317,
#  'precision': 0.8078770413064361,
#  'mAP': 0.6793720680572971,
#  'F1': 0.7542600896860986}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %%
# train_w_val
custEval = CustomEvaluator('ssdd_train/train_w_val', output_dir=cfg.OUTPUT_DIR)
val_loader = build_detection_test_loader(cfg, 'ssdd_train/train_w_val')

inference = inference_on_dataset(trainer.model, val_loader, custEval)
# Out:
# [06/25 18:50:34 d2.data.datasets.coco]: Converting annotations of dataset 'ssdd_train/train_w_val' to COCO format ...)
# [06/25 18:50:34 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [06/25 18:50:35 d2.data.datasets.coco]: Conversion finished, #images: 5100, #annotations: 2994
# [06/25 18:50:35 d2.data.datasets.coco]: Caching COCO format annotations at './ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/ssdd_train/train_w_val_coco_format.json' ...
# [06/25 18:50:35 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/25 18:50:35 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/25 18:50:35 d2.data.common]: Serializing 5100 elements to byte tensors and concatenating them all ...
# [06/25 18:50:35 d2.data.common]: Serialized dataset takes 0.86 MiB
# [06/25 18:50:35 d2.evaluation.evaluator]: Start inference on 5100 batches
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [06/25 18:50:37 d2.evaluation.evaluator]: Inference done 11/5100. Dataloading: 0.0018 s/iter. Inference: 0.1145 s/iter. Eval: 0.0058 s/iter. Total: 0.1221 s/iter. ETA=0:10:21
# [06/25 18:50:42 d2.evaluation.evaluator]: Inference done 47/5100. Dataloading: 0.0044 s/iter. Inference: 0.1165 s/iter. Eval: 0.0182 s/iter. Total: 0.1393 s/iter. ETA=0:11:43
# [06/25 18:50:47 d2.evaluation.evaluator]: Inference done 86/5100. Dataloading: 0.0033 s/iter. Inference: 0.1139 s/iter. Eval: 0.0169 s/iter. Total: 0.1342 s/iter. ETA=0:11:13
# [06/25 18:50:52 d2.evaluation.evaluator]: Inference done 124/5100. Dataloading: 0.0028 s/iter. Inference: 0.1134 s/iter. Eval: 0.0179 s/iter. Total: 0.1343 s/iter. ETA=0:11:08
# [06/25 18:50:57 d2.evaluation.evaluator]: Inference done 155/5100. Dataloading: 0.0030 s/iter. Inference: 0.1145 s/iter. Eval: 0.0225 s/iter. Total: 0.1402 s/iter. ETA=0:11:33
# [06/25 18:51:02 d2.evaluation.evaluator]: Inference done 190/5100. Dataloading: 0.0028 s/iter. Inference: 0.1134 s/iter. Eval: 0.0249 s/iter. Total: 0.1412 s/iter. ETA=0:11:33
# [06/25 18:51:08 d2.evaluation.evaluator]: Inference done 224/5100. Dataloading: 0.0027 s/iter. Inference: 0.1127 s/iter. Eval: 0.0270 s/iter. Total: 0.1426 s/iter. ETA=0:11:35
# [06/25 18:51:13 d2.evaluation.evaluator]: Inference done 253/5100. Dataloading: 0.0027 s/iter. Inference: 0.1127 s/iter. Eval: 0.0310 s/iter. Total: 0.1466 s/iter. ETA=0:11:50
# [06/25 18:51:18 d2.evaluation.evaluator]: Inference done 286/5100. Dataloading: 0.0026 s/iter. Inference: 0.1119 s/iter. Eval: 0.0327 s/iter. Total: 0.1475 s/iter. ETA=0:11:49
# [06/25 18:51:23 d2.evaluation.evaluator]: Inference done 318/5100. Dataloading: 0.0026 s/iter. Inference: 0.1115 s/iter. Eval: 0.0348 s/iter. Total: 0.1490 s/iter. ETA=0:11:52
# [06/25 18:51:28 d2.evaluation.evaluator]: Inference done 346/5100. Dataloading: 0.0026 s/iter. Inference: 0.1114 s/iter. Eval: 0.0375 s/iter. Total: 0.1516 s/iter. ETA=0:12:00
# [06/25 18:51:33 d2.evaluation.evaluator]: Inference done 377/5100. Dataloading: 0.0025 s/iter. Inference: 0.1110 s/iter. Eval: 0.0390 s/iter. Total: 0.1526 s/iter. ETA=0:12:00
# [06/25 18:51:38 d2.evaluation.evaluator]: Inference done 405/5100. Dataloading: 0.0025 s/iter. Inference: 0.1107 s/iter. Eval: 0.0413 s/iter. Total: 0.1546 s/iter. ETA=0:12:05
# [06/25 18:51:43 d2.evaluation.evaluator]: Inference done 431/5100. Dataloading: 0.0025 s/iter. Inference: 0.1106 s/iter. Eval: 0.0439 s/iter. Total: 0.1572 s/iter. ETA=0:12:13
# [06/25 18:51:48 d2.evaluation.evaluator]: Inference done 462/5100. Dataloading: 0.0025 s/iter. Inference: 0.1103 s/iter. Eval: 0.0449 s/iter. Total: 0.1578 s/iter. ETA=0:12:11
# [06/25 18:51:54 d2.evaluation.evaluator]: Inference done 486/5100. Dataloading: 0.0025 s/iter. Inference: 0.1101 s/iter. Eval: 0.0476 s/iter. Total: 0.1604 s/iter. ETA=0:12:20
# [06/25 18:51:59 d2.evaluation.evaluator]: Inference done 512/5100. Dataloading: 0.0025 s/iter. Inference: 0.1101 s/iter. Eval: 0.0496 s/iter. Total: 0.1624 s/iter. ETA=0:12:25
# [06/25 18:53:15 d2.evaluation.evaluator]: Inference done 844/5100. Dataloading: 0.0025 s/iter. Inference: 0.1089 s/iter. Eval: 0.0777 s/iter. Total: 0.1893 s/iter. ETA=0:13:25
# [06/25 18:53:20 d2.evaluation.evaluator]: Inference done 864/5100. Dataloading: 0.0025 s/iter. Inference: 0.1088 s/iter. Eval: 0.0795 s/iter. Total: 0.1911 s/iter. ETA=0:13:29
# [06/25 18:53:26 d2.evaluation.evaluator]: Inference done 882/5100. Dataloading: 0.0025 s/iter. Inference: 0.1088 s/iter. Eval: 0.0815 s/iter. Total: 0.1930 s/iter. ETA=0:13:34
# [06/25 18:53:31 d2.evaluation.evaluator]: Inference done 903/5100. Dataloading: 0.0025 s/iter. Inference: 0.1087 s/iter. Eval: 0.0828 s/iter. Total: 0.1943 s/iter. ETA=0:13:35
# [06/25 18:53:36 d2.evaluation.evaluator]: Inference done 921/5100. Dataloading: 0.0025 s/iter. Inference: 0.1087 s/iter. Eval: 0.0849 s/iter. Total: 0.1963 s/iter. ETA=0:13:40
# [06/25 18:53:41 d2.evaluation.evaluator]: Inference done 940/5100. Dataloading: 0.0025 s/iter. Inference: 0.1087 s/iter. Eval: 0.0865 s/iter. Total: 0.1978 s/iter. ETA=0:13:42
# [06/25 18:53:46 d2.evaluation.evaluator]: Inference done 960/5100. Dataloading: 0.0025 s/iter. Inference: 0.1086 s/iter. Eval: 0.0877 s/iter. Total: 0.1990 s/iter. ETA=0:13:43
# [06/25 18:53:51 d2.evaluation.evaluator]: Inference done 975/5100. Dataloading: 0.0025 s/iter. Inference: 0.1086 s/iter. Eval: 0.0899 s/iter. Total: 0.2011 s/iter. ETA=0:13:49
# [06/25 18:53:57 d2.evaluation.evaluator]: Inference done 994/5100. Dataloading: 0.0025 s/iter. Inference: 0.1085 s/iter. Eval: 0.0914 s/iter. Total: 0.2027 s/iter. ETA=0:13:52
# [06/25 18:54:02 d2.evaluation.evaluator]: Inference done 1013/5100. Dataloading: 0.0025 s/iter. Inference: 0.1085 s/iter. Eval: 0.0927 s/iter. Total: 0.2039 s/iter. ETA=0:13:53
# [06/25 18:54:07 d2.evaluation.evaluator]: Inference done 1027/5100. Dataloading: 0.0025 s/iter. Inference: 0.1085 s/iter. Eval: 0.0948 s/iter. Total: 0.2060 s/iter. ETA=0:13:59
# [06/25 18:54:12 d2.evaluation.evaluator]: Inference done 1045/5100. Dataloading: 0.0025 s/iter. Inference: 0.1084 s/iter. Eval: 0.0962 s/iter. Total: 0.2073 s/iter. ETA=0:14:00
# [06/25 18:54:17 d2.evaluation.evaluator]: Inference done 1064/5100. Dataloading: 0.0025 s/iter. Inference: 0.1084 s/iter. Eval: 0.0973 s/iter. Total: 0.2084 s/iter. ETA=0:14:00
# [06/25 18:54:22 d2.evaluation.evaluator]: Inference done 1078/5100. Dataloading: 0.0025 s/iter. Inference: 0.1084 s/iter. Eval: 0.0995 s/iter. Total: 0.2105 s/iter. ETA=0:14:06
# [06/25 18:54:27 d2.evaluation.evaluator]: Inference done 1096/5100. Dataloading: 0.0025 s/iter. Inference: 0.1083 s/iter. Eval: 0.1006 s/iter. Total: 0.2117 s/iter. ETA=0:14:07
# [06/25 18:54:33 d2.evaluation.evaluator]: Inference done 1114/5100. Dataloading: 0.0025 s/iter. Inference: 0.1083 s/iter. Eval: 0.1019 s/iter. Total: 0.2129 s/iter. ETA=0:14:08
# [06/25 18:54:38 d2.evaluation.evaluator]: Inference done 1128/5100. Dataloading: 0.0025 s/iter. Inference: 0.1083 s/iter. Eval: 0.1040 s/iter. Total: 0.2150 s/iter. ETA=0:14:14
# [06/25 18:54:43 d2.evaluation.evaluator]: Inference done 1147/5100. Dataloading: 0.0025 s/iter. Inference: 0.1083 s/iter. Eval: 0.1051 s/iter. Total: 0.2160 s/iter. ETA=0:14:13
# [06/25 18:54:48 d2.evaluation.evaluator]: Inference done 1164/5100. Dataloading: 0.0025 s/iter. Inference: 0.1082 s/iter. Eval: 0.1065 s/iter. Total: 0.2174 s/iter. ETA=0:14:15
# [06/25 18:54:53 d2.evaluation.evaluator]: Inference done 1178/5100. Dataloading: 0.0025 s/iter. Inference: 0.1082 s/iter. Eval: 0.1082 s/iter. Total: 0.2191 s/iter. ETA=0:14:19
# [06/25 18:54:58 d2.evaluation.evaluator]: Inference done 1195/5100. Dataloading: 0.0025 s/iter. Inference: 0.1082 s/iter. Eval: 0.1093 s/iter. Total: 0.2202 s/iter. ETA=0:14:19
# [06/25 18:55:04 d2.evaluation.evaluator]: Inference done 1210/5100. Dataloading: 0.0025 s/iter. Inference: 0.1082 s/iter. Eval: 0.1109 s/iter. Total: 0.2217 s/iter. ETA=0:14:22
# [06/25 18:55:09 d2.evaluation.evaluator]: Inference done 1224/5100. Dataloading: 0.0025 s/iter. Inference: 0.1081 s/iter. Eval: 0.1124 s/iter. Total: 0.2233 s/iter. ETA=0:14:25
# [06/25 18:55:14 d2.evaluation.evaluator]: Inference done 1241/5100. Dataloading: 0.0025 s/iter. Inference: 0.1081 s/iter. Eval: 0.1136 s/iter. Total: 0.2244 s/iter. ETA=0:14:25
# [06/25 18:55:19 d2.evaluation.evaluator]: Inference done 1255/5100. Dataloading: 0.0025 s/iter. Inference: 0.1081 s/iter. Eval: 0.1152 s/iter. Total: 0.2260 s/iter. ETA=0:14:28
# [06/25 18:55:24 d2.evaluation.evaluator]: Inference done 1270/5100. Dataloading: 0.0025 s/iter. Inference: 0.1081 s/iter. Eval: 0.1168 s/iter. Total: 0.2276 s/iter. ETA=0:14:31
# [06/25 18:55:30 d2.evaluation.evaluator]: Inference done 1287/5100. Dataloading: 0.0025 s/iter. Inference: 0.1081 s/iter. Eval: 0.1179 s/iter. Total: 0.2287 s/iter. ETA=0:14:31
# [06/25 18:55:35 d2.evaluation.evaluator]: Inference done 1300/5100. Dataloading: 0.0025 s/iter. Inference: 0.1081 s/iter. Eval: 0.1197 s/iter. Total: 0.2305 s/iter. ETA=0:14:35
# [06/25 18:55:40 d2.evaluation.evaluator]: Inference done 1315/5100. Dataloading: 0.0025 s/iter. Inference: 0.1080 s/iter. Eval: 0.1210 s/iter. Total: 0.2317 s/iter. ETA=0:14:36
# [06/25 18:55:45 d2.evaluation.evaluator]: Inference done 1331/5100. Dataloading: 0.0025 s/iter. Inference: 0.1080 s/iter. Eval: 0.1220 s/iter. Total: 0.2327 s/iter. ETA=0:14:36
# [06/25 18:55:50 d2.evaluation.evaluator]: Inference done 1343/5100. Dataloading: 0.0025 s/iter. Inference: 0.1080 s/iter. Eval: 0.1239 s/iter. Total: 0.2346 s/iter. ETA=0:14:41
# [06/25 18:55:55 d2.evaluation.evaluator]: Inference done 1358/5100. Dataloading: 0.0025 s/iter. Inference: 0.1080 s/iter. Eval: 0.1250 s/iter. Total: 0.2357 s/iter. ETA=0:14:42
# [06/25 18:56:01 d2.evaluation.evaluator]: Inference done 1374/5100. Dataloading: 0.0025 s/iter. Inference: 0.1080 s/iter. Eval: 0.1261 s/iter. Total: 0.2368 s/iter. ETA=0:14:42
# [06/25 18:56:06 d2.evaluation.evaluator]: Inference done 1386/5100. Dataloading: 0.0025 s/iter. Inference: 0.1080 s/iter. Eval: 0.1279 s/iter. Total: 0.2385 s/iter. ETA=0:14:45
# [06/25 18:56:11 d2.evaluation.evaluator]: Inference done 1402/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1289 s/iter. Total: 0.2395 s/iter. ETA=0:14:45
# [06/25 18:56:16 d2.evaluation.evaluator]: Inference done 1417/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1301 s/iter. Total: 0.2408 s/iter. ETA=0:14:46
# [06/25 18:56:21 d2.evaluation.evaluator]: Inference done 1429/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1317 s/iter. Total: 0.2423 s/iter. ETA=0:14:49
# [06/25 18:56:26 d2.evaluation.evaluator]: Inference done 1444/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1327 s/iter. Total: 0.2433 s/iter. ETA=0:14:49
# [06/25 18:56:31 d2.evaluation.evaluator]: Inference done 1457/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1340 s/iter. Total: 0.2446 s/iter. ETA=0:14:50
# [06/25 18:56:37 d2.evaluation.evaluator]: Inference done 1470/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1354 s/iter. Total: 0.2460 s/iter. ETA=0:14:52
# [06/25 18:56:42 d2.evaluation.evaluator]: Inference done 1485/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1364 s/iter. Total: 0.2470 s/iter. ETA=0:14:52
# [06/25 18:56:47 d2.evaluation.evaluator]: Inference done 1498/5100. Dataloading: 0.0025 s/iter. Inference: 0.1079 s/iter. Eval: 0.1378 s/iter. Total: 0.2484 s/iter. ETA=0:14:54
# [06/25 18:56:52 d2.evaluation.evaluator]: Inference done 1511/5100. Dataloading: 0.0025 s/iter. Inference: 0.1078 s/iter. Eval: 0.1391 s/iter. Total: 0.2497 s/iter. ETA=0:14:56
# [06/25 18:56:58 d2.evaluation.evaluator]: Inference done 1526/5100. Dataloading: 0.0025 s/iter. Inference: 0.1078 s/iter. Eval: 0.1401 s/iter. Total: 0.2506 s/iter. ETA=0:14:55
# [06/25 18:57:03 d2.evaluation.evaluator]: Inference done 1537/5100. Dataloading: 0.0025 s/iter. Inference: 0.1078 s/iter. Eval: 0.
5100. Dataloading: 0.0029 s/iter. Inference: 0.1084 s/iter. Eval: 0.4308 s/iter. Total: 0.5427 s/iter. ETA=0:00:16
# [06/25 19:36:30 d2.evaluation.evaluator]: Inference done 5075/5100. Dataloading: 0.0029 s/iter. Inference: 0.1084 s/iter. Eval: 0.4313 s/iter. Total: 0.5432 s/iter. ETA=0:00:13
# [06/25 19:36:35 d2.evaluation.evaluator]: Inference done 5081/5100. Dataloading: 0.0029 s/iter. Inference: 0.1084 s/iter. Eval: 0.4316 s/iter. Total: 0.5436 s/iter. ETA=0:00:10
# [06/25 19:36:40 d2.evaluation.evaluator]: Inference done 5085/5100. Dataloading: 0.0029 s/iter. Inference: 0.1084 s/iter. Eval: 0.4322 s/iter. Total: 0.5441 s/iter. ETA=0:00:08
# [06/25 19:36:46 d2.evaluation.evaluator]: Inference done 5091/5100. Dataloading: 0.0029 s/iter. Inference: 0.1084 s/iter. Eval: 0.4325 s/iter. Total: 0.5445 s/iter. ETA=0:00:04
# [06/25 19:36:51 d2.evaluation.evaluator]: Inference done 5097/5100. Dataloading: 0.0029 s/iter. Inference: 0.1084 s/iter. Eval: 0.4329 s/iter. Total: 0.5448 s/iter. ETA=0:00:01
# [06/25 19:36:55 d2.evaluation.evaluator]: Total inference time: 0:46:18.281667 (0.545296 s / iter per device, on 1 devices)
# [06/25 19:36:55 d2.evaluation.evaluator]: Total inference pure compute time: 0:09:12 (0.108408 s / iter per device, on 1 devices)

# %%
# Alternatively, load predictions directly from file into custEval instance
temp = torch.load(os.path.join(cfg.OUTPUT_DIR, "ssdd_train/train_w_val_predictions.pth"))
custEval._predictions = temp

# %%
eval, plot, hist, bad_images = custEval.evaluate()
eval
# Out:
# {'TP': 2078,
#  'FP': 672,
#  'GT': 2994,
#  'FN': 916,
#  'Pd': 0.6940547762191048,
#  'Pf': 0.24436363636363637,
#  'Pm': 0.3059452237808951,
#  'recall': 0.6940547762191048,
#  'precision': 0.7556363636363637,
#  'mAP': 0.6541645188393946,
#  'F1': 0.7235376044568245}

# %%
# Precision-Recall Curve
plt.plot(plot['recalls'], plot['precisions'])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve', fontweight ="bold")
plt.show()

# %%
# Histogram of scores for all instances
plt.hist(hist['scores'])
plt.xlabel('Scores')
plt.ylabel('No. of instances')
plt.title('Histogram of scores', fontweight ="bold")
plt.show()

# %%
# Histogram of IoUs for all matching instances/gt boxes
plt.hist(hist['gt_overlap'])
plt.xlabel('IoU')
plt.ylabel('No. of gt boxes')
plt.title('Histogram of IoUs', fontweight ="bold")
plt.show()

# %% [markdown]
# # Evaluation using the trained model
#
# To run inference using the trained model on the validation/test dataset, we first create a predictor using the model we just trained.

# %%
# Inference should use the config with parameters that are used in training
# cfg now already contains everything we've set previously. We changed it a little bit for inference:
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth") # Load custom weights
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # (default: 0.05)
cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5  # (default: 0.5)

predictor = DefaultPredictor(cfg)
# Out:
# [06/25 19:37:01 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./ModelOutput/faster_rcnn_R_101_FPN_3x_5CO/model_final.pth ...

# %% [markdown]
# ## Visualization
#
# Output images where predictions are wrong for error analysis.

# %%
#from detectron2.utils.visualizer import ColorMode

dataset_dicts = get_dict("train/train_w_val")   # must be "test", "test_offshore", "test_inshore"

bad_images_ind = [i['image_id'] for i in bad_images]

# Filter out pics w/o annotations
dataset_dicts_anns = []
for i in dataset_dicts:
  if i['image_id'] in bad_images_ind:
    dataset_dicts_anns.append(i)

# %%
len(dataset_dicts_anns)
# Out:
# 349

# %%
def printImage(ann, metadata, predictor = None, predFlag = False):
  #from detectron2.utils.visualizer import Visualizer

  im = cv2.imread(ann["file_name"])
  v = Visualizer(im[:, :, ::-1],
                 metadata=metadata,
                 scale=0.5)

  if predFlag:
    outputs = predictor(im)  # format is documented at https://detectron2.readthedocs.io/tutorials/models.html#model-output-format
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  else:
    out = v.draw_dataset_dict(ann)

  image = out.get_image()[:, :, ::-1]

  return image

# %%
os.makedirs(model_name + "/predImages_eval_bad", exist_ok=True)  # Make a directory for output images

# %%
from cv2 import hconcat
random.seed(1)
#set.seed(1)

num_samples = 3
#num_samples = len(dataset_dicts_anns)

for d in random.sample(dataset_dicts_anns, num_samples):
  image1 = printImage(d, test_metadata, predictor, True)  # Prediction
  image2 = printImage(d, test_metadata, False)  # Ground truth
  image3 = hconcat([image1, image2])

  cv2_imshow(image3) # display an image
  cv2.imwrite(model_name + '/predImages_eval_bad/' + str(d["image_id"] + '.jpg'), image3)  # save an image
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F3406020BB0>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F33FC2391E0>
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F33FC2391E0>
